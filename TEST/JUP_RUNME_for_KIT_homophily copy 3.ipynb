# %%
# Specify the parameter values
va_value = 0.5
s2vh_value = 0.8
wsp_value = 0.1

# Use the %run magic command to execute the script with specified parameters
# %run RUNME_for_KIT_homophily --va $va_value --s2vh $s2vh_value --wsp $wsp_value
# Out:
# Trial: 0 of 1 alpha = 100
# The simulations are now completed

# %%
import igraph as ig
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap


cmap1 = LinearSegmentedColormap.from_list("vertex_cmap", ["blue", "red"])

g = ig.Graph.Read_Adjacency('ADJ.csv', mode = 'undirected')


BB = pd.read_csv('hist_B.csv')
BB = BB.to_numpy()
B = BB[0,:]


for indx, v in enumerate(g.vs):
    if B[indx] > 0.5:
        #print(B[indx], "became blue")
        v['color'] = 'blue'
    else:
        #print(B[indx], "became red")
        v['color'] = 'red'

#print("sum of B = ", np.sum(B))
fig, ax = plt.subplots()
#ig.plot(g, target=ax)
ig.plot(g, target = ax, vertex_size = 0.1, edge_width = 0.5, layout = ('circular'), bbox = (0,0,300,300), edge_curved = True)

fig.savefig('Fig2.png', dpi = 600)
#print(black_count)

# %%
import igraph as ig
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap


cmap1 = LinearSegmentedColormap.from_list("vertex_cmap", ["blue", "red"])

g = ig.Graph.Read_Adjacency('ADJ.csv', mode = 'undirected')


BB = pd.read_csv('hist_B.csv')
BB = BB.to_numpy()
B = BB[0,:]


for indx, v in enumerate(g.vs):
    if B[indx] > 0.5:
        #print(B[indx], "became blue")
        v['color'] = 'red'
    else:
        #print(B[indx], "became red")
        v['color'] = 'red'

#print("sum of B = ", np.sum(B))
fig, ax = plt.subplots()
#ig.plot(g, target=ax)
ig.plot(g, target = ax, vertex_size = 0.1, edge_width = 0.5, layout = ('circular'), bbox = (0,0,300,300), edge_curved = True)

colors = [v['color'] for v in g.vs]
#print(colors)

# count how many "black" there are
black_count = colors.count('black')

fig.savefig('Fig1.png', dpi = 600)
#print(black_count)

# %%
import igraph as ig
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap


cmap1 = LinearSegmentedColormap.from_list("vertex_cmap", ["blue", "red"])

g = ig.Graph.Read_Adjacency('ADJ.csv', mode = 'undirected')


BB = pd.read_csv('hist_B.csv')
BB = BB.to_numpy()
B = BB[-1,:]


for indx, v in enumerate(g.vs):
    if B[indx] > 0.5:
        #print(B[indx], "became blue")
        v['color'] = 'blue'
    else:
        #print(B[indx], "became red")
        v['color'] = 'red'

#print("sum of B = ", np.sum(B))
fig, ax = plt.subplots()
#ig.plot(g, target=ax)
ig.plot(g, target = ax, vertex_size = 0.1, edge_width = 0.5, layout = ('circular'), bbox = (0,0,300,300), edge_curved = True)

fig.savefig('Fig3.png', dpi = 600)
#print(black_count)

# %%
plt.plot(Bend,'.')
